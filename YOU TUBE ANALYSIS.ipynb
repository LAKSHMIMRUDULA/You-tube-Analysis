# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cd D:\DATA SCIENCE PROJECTS\DATASETS
# Out:
# D:\DATA SCIENCE PROJECTS\DATASETS

# %%
df=pd.read_csv("USvideos.csv")
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                      nigahiga           24  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %%
print(df.shape)
# Out:
# (40949, 16)

# %%
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
# data cleaning changing trending date publish time in datetime dtype

df["trending_date"]=pd.to_datetime(pd.Series(df['trending_date'].apply(lambda x:'20'+x[0:2]+'.'+x[6:]+'.'+x[3:5])))

df["publish_time"]=pd.to_datetime(pd.Series(df['publish_time'].apply(lambda x:x[:19])))
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE    2017-11-14
# 1      1ZAPwfrtAFY    2017-11-14
# 2      5qpjK5DgCt4    2017-11-14
# 3      puqaWrEC7tY    2017-11-14
# 4      d380meD0W0M    2017-11-14
# ...            ...           ...
# 40944  BZt0qjTWNhw    2018-06-14
# 40945  1h7KV2sjUWY    2018-06-14
# 40946  D6Oy4LfoqsU    2018-06-14
# 40947  oV0zkMe1K8s    2018-06-14
# 40948  ooyjaVdt-jA    2018-06-14
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id        publish_time  \
# 0                  CaseyNeistat           22 2017-11-13 17:13:01
# 1               LastWeekTonight           24 2017-11-13 07:30:00
# 2                  Rudy Mancuso           23 2017-11-12 19:05:24
# 3         Good Mythical Morning           24 2017-11-13 11:00:04
# 4                      nigahiga           24 2017-11-12 18:01:41
# ...                         ...          ...                 ...
# 40944             AaronsAnimals           15 2018-05-18 13:00:04
# 40945                  zefrank1           22 2018-05-18 01:00:06
# 40946                Brad Mondo           24 2018-05-18 17:34:22
# 40947  How It Should Have Ended            1 2018-05-17 17:00:04
# 40948              Call of Duty           20 2018-05-17 17:09:38
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
df.dtypes
# Out:
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                        int64
# publish_time              datetime64[ns]
# tags                              object
# views                              int64
# likes                              int64
# dislikes                           int64
# comment_count                      int64
# thumbnail_link                    object
# comments_disabled                   bool
# ratings_disabled                    bool
# video_error_or_removed              bool
# description                       object
# dtype: object

# %%
df["description"]=df["description"].fillna("")
df.isnull().sum()
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# dtype: int64

# %%
# dataset collection years
day=df["trending_date"].dt.strftime('%Y')
my_dict=(day.value_counts()).to_dict()
count=pd.DataFrame(list(my_dict.items()),columns=["Trending year","No.of videos"])
fig=plt.figure(figsize=(10,5))
plt.bar(count["Trending year"],count["No.of videos"],color=["yellow","pink","cyan"],width=0.5)
plt.xlabel("Trending year")
plt.ylabel("No.of videos")
plt.show()

# %%
day=df["publish_time"].dt.day_name()
my_dict=(day.value_counts()).to_dict()
count=pd.DataFrame(list(my_dict.items()),columns=["Publishing Day","No.of videos"])
fig=plt.figure(figsize=(10,5))
plt.bar(count["Publishing Day"],count["No.of videos"],color=["yellow","pink","cyan"],width=0.5)
plt.xlabel("Publishing Day")
plt.ylabel("No.of videos")
plt.show()

# %%
# NOW WE CAN SEE WHICH PUBLISHING HOURS HAVE THE LARGEST NO OF TRENDING VIDEOS

hour=df.publish_time.apply(lambda x:x.strftime("%H"))
my_dict=(hour.value_counts()).to_dict()
count=pd.DataFrame(list(my_dict.items()),columns=["Publishing hour","No.of videos"])
fig=plt.figure(figsize=(10,5))
plt.bar(count["Publishing hour"],count["No.of videos"],color=["yellow","pink","cyan"],width=0.5)
plt.xlabel("Publishing hour")
plt.ylabel("No.of videos")
plt.show()

# %%
df["trending days_difference"]=df.apply(lambda row:(row.trending_date-row.publish_time).days,axis=1)
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE    2017-11-14
# 1      1ZAPwfrtAFY    2017-11-14
# 2      5qpjK5DgCt4    2017-11-14
# 3      puqaWrEC7tY    2017-11-14
# 4      d380meD0W0M    2017-11-14
# ...            ...           ...
# 40944  BZt0qjTWNhw    2018-06-14
# 40945  1h7KV2sjUWY    2018-06-14
# 40946  D6Oy4LfoqsU    2018-06-14
# 40947  oV0zkMe1K8s    2018-06-14
# 40948  ooyjaVdt-jA    2018-06-14
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id        publish_time  \
# 0                  CaseyNeistat           22 2017-11-13 17:13:01
# 1               LastWeekTonight           24 2017-11-13 07:30:00
# 2                  Rudy Mancuso           23 2017-11-12 19:05:24
# 3         Good Mythical Morning           24 2017-11-13 11:00:04
# 4                      nigahiga           24 2017-11-12 18:01:41
# ...                         ...          ...                 ...
# 40944             AaronsAnimals           15 2018-05-18 13:00:04
# 40945                  zefrank1           22 2018-05-18 01:00:06
# 40946                Brad Mondo           24 2018-05-18 17:34:22
# 40947  How It Should Have Ended            1 2018-05-17 17:00:04
# 40948              Call of Duty           20 2018-05-17 17:09:38
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description  \
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
#        trending days_difference
# 0                             0
# 1                             0
# 2                             1
# 3                             0
# 4                             1
# ...                         ...
# 40944                        26
# 40945                        26
# 40946                        26
# 40947                        27
# 40948                        27
#
# [40949 rows x 17 columns]

# %%
df["trending days_difference"].replace({-1:0},inplace=True)

# %%
print(df["trending days_difference"].max())
print(df["trending days_difference"].min())
# Out:
# 4214
# 0

# %%
# description of numerical columns

pd.options.display.float_format="{:.2f}".format
df.describe()
# Out:
#        category_id        views      likes   dislikes  comment_count  \
# count     40949.00     40949.00   40949.00   40949.00       40949.00
# mean         19.97   2360784.64   74266.70    3711.40        8446.80
# std           7.57   7394113.76  228885.34   29029.71       37430.49
# min           1.00       549.00       0.00       0.00           0.00
# 25%          17.00    242329.00    5424.00     202.00         614.00
# 50%          24.00    681861.00   18091.00     631.00        1856.00
# 75%          25.00   1823157.00   55417.00    1938.00        5755.00
# max          43.00 225211923.00 5613827.00 1674420.00     1361580.00
#
#        trending days_difference
# count                  40949.00
# mean                      15.81
# std                      146.01
# min                        0.00
# 25%                        2.00
# 50%                        4.00
# 75%                        8.00
# max                     4214.00

# %%
# plotting histograms
numerical=["views","likes","dislikes","comment_count","trending days_difference"]
color=["cyan","pink","yellow","orange","blue"]
fig,ax=plt.subplots(3,2,figsize=(20,20))
for var,i,subplot in zip(numerical,color,ax.flatten()):
    ax=df[var].hist(ax=subplot,ylabelsize=16,xlabelsize=16,color=i)
    ax.set_xlabel(var,fontsize=20)
    ax.set_ylabel("No.Of Videos",fontsize=20)
fig.tight_layout()

# %%
r=[10000000,100000,15000,30000,40]

fig,ax=plt.subplots(3,2,figsize=(20,20))
for var,i,j,subplot in zip(numerical,r,color,ax.flatten()):
    ax=df[df[var]<=i][var].hist(ax=subplot,ylabelsize=16,xlabelsize=16,color=j)
    ax.set_xlabel(var,fontsize=20)
    ax.set_ylabel("No.Of Videos",fontsize=20)
fig.tight_layout()

# %%
x=[2000000,40000,2000,5000,15]
for i,j in zip(numerical,x):
    c=df[i].loc[df[i]<=j].count()/df[i].count()*100
    print(i,c)
# Out:
# views 76.9811228601431
# likes 68.4900730176561
# dislikes 75.49879117927178
# comment_count 72.26305892695792
# trending days_difference 94.40279371901634

# %%
plt.scatter(df["views"],df["likes"])
plt.xlabel("Views",size=15)
plt.ylabel("Likes",size=15)
plt.show()

# %%
df["category_id"].value_counts()
# Out:
# 24    9964
# 10    6472
# 26    4146
# 23    3457
# 22    3210
# 25    2487
# 28    2401
# 1     2345
# 17    2174
# 27    1656
# 15     920
# 20     817
# 19     402
# 2      384
# 29      57
# 43      57
# Name: category_id, dtype: int64

# %%
df["category_name"]=np.nan

df.loc[(df["category_id"]==1),"category_name"]="Film and Animation"
df.loc[(df["category_id"]==2),"category_name"]="Cars and Vehicles"
df.loc[(df["category_id"]==10),"category_name"]="Music"
df.loc[(df["category_id"]==15),"category_name"]="Pets and Animals"
df.loc[(df["category_id"]==17),"category_name"]="Sports"
df.loc[(df["category_id"]==19),"category_name"]="Travel and Events"
df.loc[(df["category_id"]==20),"category_name"]="Gaming"
df.loc[(df["category_id"]==22),"category_name"]="People and Blogs"
df.loc[(df["category_id"]==23),"category_name"]="Comedy"
df.loc[(df["category_id"]==24),"category_name"]="Entertainment"
df.loc[(df["category_id"]==25),"category_name"]="News and Politics"
df.loc[(df["category_id"]==26),"category_name"]="How to and Style"
df.loc[(df["category_id"]==27),"category_name"]="Education"
df.loc[(df["category_id"]==28),"category_name"]="Science and Technology"
df.loc[(df["category_id"]==29),"category_name"]="Non profits and Activism"
df.loc[(df["category_id"]==43),"category_name"]="Shows"

# %%
my_dict=(df["category_name"].value_counts()).to_dict()
count=pd.DataFrame(list(my_dict.items()),columns=['Category','No Of Videos'])
fig=plt.figure(figsize=(10,5))
plt.bar(count['Category'],count['No Of Videos'],color=["yellow","pink","cyan"],width=0.5)
plt.xticks(rotation=90)
plt.xlabel("Category",size=15)
plt.ylabel("No Of Videos",size=15)
plt.show()

# %%
# now we will see which category has the maximum likes

a=df.groupby("category_id")
c=a["category_name","likes"].max()
print(c)
fig=plt.figure(figsize=(10,5))
plt.bar(c['category_name'],c['likes'],color=["yellow","pink","cyan"],width=0.5)
plt.xticks(rotation=90)
plt.xlabel("category_name",size=15)
plt.ylabel("likes",size=15)
plt.show()
# Out:
#                         category_name    likes
# category_id
# 1                  Film and Animation   922355
# 2                   Cars and Vehicles    97030
# 10                              Music  5613827
# 15                   Pets and Animals   178243
# 17                             Sports  1121217
# 19                  Travel and Events    42447
# 20                             Gaming   444203
# 22                   People and Blogs  2032463
# 23                             Comedy   865679
# 24                      Entertainment  3093544
# 25                  News and Politics   163338
# 26                   How to and Style   605954
# 27                          Education   240989
# 28             Science and Technology   564804
# 29           Non profits and Activism  1988746
# 43                              Shows    33261

# %% [markdown]
# Music and Entertainment has more likes
#
# Describe non numerical columns

# %%
df.describe(include="object")
# Out:
#        video_id                                       title channel_title  \
# count     40949                                       40949         40949
# unique     6282                                        6455          2207
# top      #NAME?  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!          ESPN
# freq        397                                          30           203
#
#           tags                                  thumbnail_link description  \
# count    40949                                           40949       40949
# unique    6055                                            6352        6902
# top     [none]  https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg
# freq      1535                                              30         570
#
#         category_name
# count           40949
# unique             16
# top     Entertainment
# freq             9964

# %%
grouped=df.groupby("video_id")
groups=[]
wanted_groups=[]
for key,item in grouped:
    groups.append(grouped.get_group(key))
for g in groups:
    if len(g["title"].unique())!=1:
        wanted_groups.append(g)
wanted_groups[0]
# Out:
#       video_id trending_date  \
# 92      #NAME?    2017-11-14
# 352     #NAME?    2017-11-15
# 433     #NAME?    2017-11-16
# 546     #NAME?    2017-11-16
# 578     #NAME?    2017-11-16
# ...        ...           ...
# 40133   #NAME?    2018-06-10
# 40333   #NAME?    2018-06-11
# 40546   #NAME?    2018-06-12
# 40747   #NAME?    2018-06-13
# 40749   #NAME?    2018-06-14
#
#                                                    title  \
# 92                     Animal Adventure Park Giraffe Cam
# 352                    Animal Adventure Park Giraffe Cam
# 433    24 Facts about Koalas - mental_floss List Show...
# 546        Coach Taggart Monday Presser Ahead of Arizona
# 578                    Animal Adventure Park Giraffe Cam
# ...                                                  ...
# 40133                                  We Bought A House
# 40333                                  We Bought A House
# 40546                                  We Bought A House
# 40747                                  We Bought A House
# 40749                      Dumbo Official Teaser Trailer
#
#                channel_title  category_id        publish_time  \
# 92     Animal Adventure Park           15 2017-11-12 00:18:43
# 352    Animal Adventure Park           15 2017-11-12 00:18:43
# 433             Mental Floss           27 2017-11-15 16:00:00
# 546            GoDucksdotcom           17 2017-11-13 20:41:45
# 578    Animal Adventure Park           15 2017-11-12 00:18:43
# ...                      ...          ...                 ...
# 40133           JennaMarbles           23 2018-05-16 22:33:29
# 40333           JennaMarbles           23 2018-05-16 22:33:29
# 40546           JennaMarbles           23 2018-05-16 22:33:29
# 40747           JennaMarbles           23 2018-05-16 22:33:29
# 40749  Disney Movie Trailers            1 2018-06-13 07:00:00
#
#                                                     tags    views   likes  \
# 92     Giraffe|"Zoo"|"New York"|"giraffe cam"|"Animal...    45455    2282
# 352    Giraffe|"Zoo"|"New York"|"giraffe cam"|"Animal...    45965    2284
# 433    john green|"mental floss"|"koalas"|"marsupial"...    21740     979
# 546    Oregon|"Ducks"|"college athletics"|"college fo...      687      10
# 578    Giraffe|"Zoo"|"New York"|"giraffe cam"|"Animal...    46260    2286
# ...                                                  ...      ...     ...
# 40133  jenna|"marbles"|"mourey"|"we"|"bought"|"a hous...  3412175  336600
# 40333  jenna|"marbles"|"mourey"|"we"|"bought"|"a hous...  3419284  336855
# 40546  jenna|"marbles"|"mourey"|"we"|"bought"|"a hous...  3430539  337332
# 40747  jenna|"marbles"|"mourey"|"we"|"bought"|"a hous...  3440148  337688
# 40749  Disney|"Walt Disney Studios"|"Dumbo"|"Flying E...  4427381   96391
#
#        dislikes  comment_count  \
# 92           35             17
# 352          35             17
# 433           5             93
# 546           2              5
# 578          35             17
# ...         ...            ...
# 40133      1837          49132
# 40333      1839          49151
# 40546      1842          49180
# 40747      1844          49195
# 40749      5508          12726
#
#                                        thumbnail_link  comments_disabled  \
# 92     https://i.ytimg.com/vi/-OK9i1_YYYc/default.jpg              False
# 352    https://i.ytimg.com/vi/-OK9i1_YYYc/default.jpg              False
# 433    https://i.ytimg.com/vi/-oXybog2IuI/default.jpg              False
# 546    https://i.ytimg.com/vi/-JVITToppE0/default.jpg              False
# 578    https://i.ytimg.com/vi/-OK9i1_YYYc/default.jpg              False
# ...                                               ...                ...
# 40133  https://i.ytimg.com/vi/-kTWIm7m4Uw/default.jpg              False
# 40333  https://i.ytimg.com/vi/-kTWIm7m4Uw/default.jpg              False
# 40546  https://i.ytimg.com/vi/-kTWIm7m4Uw/default.jpg              False
# 40747  https://i.ytimg.com/vi/-kTWIm7m4Uw/default.jpg              False
# 40749  https://i.ytimg.com/vi/-QPdRfqTnt4/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 92                False                   False
# 352               False                   False
# 433               False                   False
# 546               False                   False
# 578               False                   False
# ...                 ...                     ...
# 40133             False                   False
# 40333             False                   False
# 40546             False                   False
# 40747             False                   False
# 40749             False                   False
#
#                                              description  \
# 92     November 2017 Giraffe Cam Hours\n\nEnjoy your ...
# 352    November 2017 Giraffe Cam Hours\n\nEnjoy your ...
# 433    A weekly show where knowledge junkies get thei...
# 546    Coach Taggart addresses the media ahead of the...
# 578    November 2017 Giraffe Cam Hours\n\nEnjoy your ...
# ...                                                  ...
# 40133  This house means the world to us.  The absolut...
# 40333  This house means the world to us.  The absolut...
# 40546  This house means the world to us.  The absolut...
# 40747  This house means the world to us.  The absolut...
# 40749  Watch the teaser trailer for Tim Burton’s all-...
#
#        trending days_difference       category_name
# 92                            1    Pets and Animals
# 352                           2    Pets and Animals
# 433                           0           Education
# 546                           2              Sports
# 578                           3    Pets and Animals
# ...                         ...                 ...
# 40133                        24              Comedy
# 40333                        25              Comedy
# 40546                        26              Comedy
# 40747                        27              Comedy
# 40749                         0  Film and Animation
#
# [397 rows x 18 columns]

# %% [markdown]
# How many trending videos have capitalised word

# %%
def contains_capitalized_word(s):
    for w in s.split():
        if w.isupper():
            return True
    return False
df["contains_capitalized"]=df["title"].apply(contains_capitalized_word)
value_counts=df["contains_capitalized"].value_counts().to_dict()
plt.pie([value_counts[False],value_counts[True]],labels=["No","Yes"],colors=["black","orange"],startangle=45)
plt.title("Title contains capitalized word")
plt.show()

# %%
df["contains_capitalized"].value_counts(normalize=True)*100
# Out:
# False   56.04
# True    43.96
# Name: contains_capitalized, dtype: float64

# %%
df["title_length"]=df["title"].apply(lambda x:len(x))
ax=df["title_length"].hist(color="pink")
ax.axvline(df["title_length"].mean(),color="k",linestyle="dashed",linewidth=1)
min_ylim,max_ylim=plt.ylim()
ax.text(df["title_length"].mean(),max_ylim,'Mean:{:.2f}'.format(df['title_length'].mean()))
plt.xlabel("title_length",size=15)
plt.ylabel("No Of Videos",size=15)
plt.show()

# %% [markdown]
# we can see that distribution is normal max between 30 to 60

# %%
fig=plt.figure(figsize=(10,7))
plt.boxplot(df.title_length)
plt.xlabel("title length")
plt.show()

# %%
plt.scatter(df["title_length"],df["likes"],color="yellow")
plt.xlabel("Title length",size=15)
plt.ylabel("likes",size=15)
plt.show()

# %% [markdown]
# which channel has the most trending videos

# %%
cdf=df.groupby("channel_title").size().reset_index(name="video_count").sort_values("video_count",ascending=False).head(20)
cdf_sorted=cdf.sort_values("video_count")
fig=plt.figure(figsize=(12,6))
plt.barh(cdf_sorted["channel_title"],cdf_sorted["video_count"],color=["yellow","pink","cyan"])
plt.xlabel("No Of Videos",size=15)
plt.ylabel("Channel",size=15)
plt.show()

# %% [markdown]
# How many trending videos have an error

# %%
value_counts=df["video_error_or_removed"].value_counts().to_dict()
plt.pie([value_counts[False],value_counts[True]],labels=["No","Yes"],colors=["black","orange"])
plt.title("video error or removed")
plt.show()

# %%
df["video_error_or_removed"].value_counts()
# Out:
# False    40926
# True        23
# Name: video_error_or_removed, dtype: int64

# %% [markdown]
# How many videos have their comments disabled

# %%
value_counts=df["comments_disabled"].value_counts().to_dict()
plt.pie([value_counts[False],value_counts[True]],labels=["No","Yes"],colors=["black","orange"])
plt.title("comments_disabled")
plt.show()

# %% [markdown]
# how many trending videos have their rating disabled

# %%
value_counts=df["ratings_disabled"].value_counts().to_dict()
plt.pie([value_counts[False],value_counts[True]],labels=["No","Yes"],colors=["black","orange"])
plt.title("ratings_disabled")
plt.show()

# %% [markdown]
# how many videos have both ratings and comments disabled

# %%
len(df[(df["comments_disabled"]==True)&(df["ratings_disabled"]==True)].index)
# Out:
# 106

# %%
fig=plt.figure(figsize=(15,10))
df2=df.groupby(["comments_disabled","category_name"])["category_name"].count().unstack("comments_disabled").fillna(0)
df2.plot(kind="bar",stacked=True)
plt.show()

# %%
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE    2017-11-14
# 1      1ZAPwfrtAFY    2017-11-14
# 2      5qpjK5DgCt4    2017-11-14
# 3      puqaWrEC7tY    2017-11-14
# 4      d380meD0W0M    2017-11-14
# ...            ...           ...
# 40944  BZt0qjTWNhw    2018-06-14
# 40945  1h7KV2sjUWY    2018-06-14
# 40946  D6Oy4LfoqsU    2018-06-14
# 40947  oV0zkMe1K8s    2018-06-14
# 40948  ooyjaVdt-jA    2018-06-14
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id        publish_time  \
# 0                  CaseyNeistat           22 2017-11-13 17:13:01
# 1               LastWeekTonight           24 2017-11-13 07:30:00
# 2                  Rudy Mancuso           23 2017-11-12 19:05:24
# 3         Good Mythical Morning           24 2017-11-13 11:00:04
# 4                      nigahiga           24 2017-11-12 18:01:41
# ...                         ...          ...                 ...
# 40944             AaronsAnimals           15 2018-05-18 13:00:04
# 40945                  zefrank1           22 2018-05-18 01:00:06
# 40946                Brad Mondo           24 2018-05-18 17:34:22
# 40947  How It Should Have Ended            1 2018-05-17 17:00:04
# 40948              Call of Duty           20 2018-05-17 17:09:38
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description  \
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
#        trending days_difference       category_name  contains_capitalized  \
# 0                             0    People and Blogs                  True
# 1                             0       Entertainment                  True
# 2                             1              Comedy                 False
# 3                             0       Entertainment                 False
# 4                             1       Entertainment                  True
# ...                         ...                 ...                   ...
# 40944                        26    Pets and Animals                 False
# 40945                        26    People and Blogs                 False
# 40946                        26       Entertainment                  True
# 40947                        27  Film and Animation                 False
# 40948                        27              Gaming                 False
#
#        title_length
# 0                34
# 1                62
# 2                53
# 3                32
# 4                24
# ...             ...
# 40944            28
# 40945            26
# 40946            84
# 40947            35
# 40948            64
#
# [40949 rows x 20 columns]

# %%
c=df.channel_title.value_counts()
c=c[c>50]
c
# Out:
# ESPN                                      203
# The Tonight Show Starring Jimmy Fallon    197
# Vox                                       193
# TheEllenShow                              193
# Netflix                                   193
#                                          ...
# Lip Sync Battle                            52
# Epicurious                                 52
# Jaiden Animations                          51
# Casey Holmes                               51
# CBS Los Angeles                            51
# Name: channel_title, Length: 203, dtype: int64

# %%
titles=list(c.index)
titles
# Out:
# ['ESPN',
#  'The Tonight Show Starring Jimmy Fallon',
#  'Vox',
#  'TheEllenShow',
#  'Netflix',
#  'The Late Show with Stephen Colbert',
#  'Jimmy Kimmel Live',
#  'Late Night with Seth Meyers',
#  'Screen Junkies',
#  'NBA',
#  'CNN',
#  'Saturday Night Live',
#  'WIRED',
#  'BuzzFeedVideo',
#  'INSIDER',
#  'The Late Late Show with James Corden',
#  'TED-Ed',
#  'Tom Scott',
#  'WWE',
#  'CollegeHumor',
#  'First We Feast',
#  'HellthyJunkFood',
#  'Tasty',
#  'Bon Appétit',
#  'Warner Bros. Pictures',
#  'FBE',
#  'jacksfilms',
#  'The King of Random',
#  'Life Noggin',
#  'Good Mythical Morning',
#  'Vanity Fair',
#  'Vogue',
#  'Safiya Nygaard',
#  'SciShow',
#  '20th Century Fox',
#  'Smosh',
#  'Dude Perfect',
#  'Marques Brownlee',
#  'Great Big Story',
#  'Marvel Entertainment',
#  'AsapSCIENCE',
#  'ABC News',
#  'NFL',
#  'The Slow Mo Guys',
#  'The Voice',
#  'James Charles',
#  'Kurzgesagt – In a Nutshell',
#  'CrazyRussianHacker',
#  "Simon's Cat",
#  'Washington Post',
#  'Binging with Babish',
#  'NikkieTutorials',
#  'Complex',
#  'E! Entertainment',
#  'You Suck At Cooking',
#  'Team Coco',
#  'Universal Pictures',
#  'Star Wars',
#  'Brave Wilderness',
#  'IISuperwomanII',
#  'NBC News',
#  'Inside Edition',
#  'REACT',
#  'Hannah Stocking',
#  'The Film Theorists',
#  'The Graham Norton Show',
#  'TODAY',
#  'Tati',
#  'CinemaSins',
#  'iJustine',
#  'Rosanna Pansino',
#  'The Verge',
#  'Refinery29',
#  'Watch What Happens Live with Andy Cohen',
#  'HBO',
#  'CaseyNeistat',
#  'The View',
#  'Laura Lee',
#  'BBC News',
#  'Bad Lip Reading',
#  'PTXofficial',
#  'itsAlexClark',
#  'nigahiga',
#  'Domics',
#  'Sony Pictures Entertainment',
#  'Nintendo',
#  'American Idol',
#  'CBS This Morning',
#  'BBC Radio 1',
#  'Charlie Puth',
#  'The Dodo',
#  'Entertainment Tonight',
#  'BuzzFeedBlue',
#  'CBS News',
#  'Matt Stonie',
#  'How To Cake It',
#  'LaurDIY',
#  'ibighit',
#  'LOL Network',
#  'Unbox Therapy',
#  'The New York Times',
#  'Michelle Khare',
#  'ExplosmEntertainment',
#  'Good Morning America',
#  'William Osman',
#  'FOX Soccer',
#  'Focus Features',
#  'As/Is',
#  'SpaceX',
#  'How Ridiculous',
#  'Grace Helbig',
#  'Will Smith',
#  'Studio C',
#  'Rudy Mancuso',
#  'TIME',
#  'NBC Sports',
#  'Lucas the Spider',
#  'Guava Juice',
#  'SMTOWN',
#  'Amber Scholl',
#  'Half as Interesting',
#  'Simone Giertz',
#  "What's Inside?",
#  'vlogbrothers',
#  'ThreadBanger',
#  'KathleenLights',
#  'WOWPresents',
#  'Lele Pons',
#  'Gus Johnson',
#  'Matthias',
#  'Hydraulic Press Channel',
#  'colinfurze',
#  'EverythingApplePro',
#  'Linus Tech Tips',
#  'Strictly Dumpling',
#  'ColliderVideos',
#  'Austin Evans',
#  'AaronsAnimals',
#  'Mr. Kate',
#  'Billboard',
#  'jypentertainment',
#  'Cut',
#  'Mike Boyd',
#  'Full Frontal with Samantha Bee',
#  'The School of Life',
#  'Markiplier',
#  'Tyler Oakley',
#  'Movieclips Trailers',
#  'Nerdwriter1',
#  'Paramount Pictures',
#  'Jackie Aina',
#  'GQ',
#  'How To Cook That',
#  'The Daily Show with Trevor Noah',
#  "Britain's Got Talent",
#  'National Geographic',
#  'Business Insider',
#  'emmymadeinjapan',
#  'Atlantic Records',
#  'RM Videos',
#  'Disney Movie Trailers',
#  'TMZ',
#  'Team Edge',
#  'MeghanTrainorVEVO',
#  'Jenny Nicholson',
#  'Marzia',
#  'JunsKitchen',
#  'ShawnMendesVEVO',
#  'MatthewSantoro',
#  'CalumScottVEVO',
#  'Breakfast Club Power 105.1 FM',
#  'Teen Vogue',
#  'SiaVEVO',
#  'The Infographics Show',
#  'AnthonyPadilla',
#  'BuzzFeed Celeb',
#  'TroyeSivanVEVO',
#  'JennaMarbles',
#  'Wendy Williams',
#  'TheReportOfTheWeek',
#  'Anwar Jibawi',
#  'FaZe Rug',
#  'Kelly Clarkson',
#  'IGN',
#  'FC Barcelona',
#  'Carli Bybel',
#  'Wendover Productions',
#  'John Campea',
#  'Papa Jake',
#  'BostonDynamics',
#  'ChainsmokersVEVO',
#  'Diplo',
#  'Lionsgate Movies',
#  'PBS Eons',
#  'Guardian News',
#  'Rooster Teeth',
#  'Simply Nailogical',
#  'MLG Highlights',
#  'Lip Sync Battle',
#  'Epicurious',
#  'Jaiden Animations',
#  'Casey Holmes',
#  'CBS Los Angeles']

# %%
data=df[df["channel_title"].isin(titles)]
data=data.reset_index()
data.drop(["index","video_id","trending_date","title","category_id","tags","thumbnail_link","description","publish_time"],axis=1,inplace=True)
data
# Out:
#                 channel_title    views   likes  dislikes  comment_count  \
# 0                CaseyNeistat   748374   57527      2966          15954
# 1                Rudy Mancuso  3191434  146033      5339           8181
# 2       Good Mythical Morning   343168   10172       666           2146
# 3                    nigahiga  2095731  132235      1989          17518
# 4                    iJustine   119180    9763       511           1434
# ...                       ...      ...     ...       ...            ...
# 18799     Saturday Night Live  8607264   66559     14179           8382
# 18800        Lucas the Spider  8300584  266267      4237          14617
# 18801  The Graham Norton Show  5564576   46351      2295           2861
# 18802          BuzzFeed Celeb  8259128  645888      4052          62610
# 18803           AaronsAnimals  1685609   38160      1385           2657
#
#        comments_disabled  ratings_disabled  video_error_or_removed  \
# 0                  False             False                   False
# 1                  False             False                   False
# 2                  False             False                   False
# 3                  False             False                   False
# 4                  False             False                   False
# ...                  ...               ...                     ...
# 18799              False             False                   False
# 18800              False             False                   False
# 18801              False             False                   False
# 18802              False             False                   False
# 18803              False             False                   False
#
#        trending days_difference           category_name  contains_capitalized  \
# 0                             0        People and Blogs                  True
# 1                             1                  Comedy                 False
# 2                             0           Entertainment                 False
# 3                             1           Entertainment                  True
# 4                             0  Science and Technology                  True
# ...                         ...                     ...                   ...
# 18799                        24           Entertainment                  True
# 18800                        25      Film and Animation                 False
# 18801                        26           Entertainment                  True
# 18802                        26        People and Blogs                  True
# 18803                        26        Pets and Animals                 False
#
#        title_length
# 0                34
# 1                53
# 2                32
# 3                24
# 4                21
# ...             ...
# 18799            19
# 18800            31
# 18801            77
# 18802            52
# 18803            28
#
# [18804 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in data.columns:
    if i in ["channel_title","comments_disabled","ratings_disabled","video_error_or_removed","category_name","contains_capitalized"]:
        data[i]=le.fit_transform(data[i])
        
    
data
# Out:
#        channel_title    views   likes  dislikes  comment_count  \
# 0                 32   748374   57527      2966          15954
# 1                130  3191434  146033      5339           8181
# 2                 60   343168   10172       666           2146
# 3                201  2095731  132235      1989          17518
# 4                196   119180    9763       511           1434
# ...              ...      ...     ...       ...            ...
# 18799            133  8607264   66559     14179           8382
# 18800             98  8300584  266267      4237          14617
# 18801            159  5564576   46351      2295           2861
# 18802             22  8259128  645888      4052          62610
# 18803              2  1685609   38160      1385           2657
#
#        comments_disabled  ratings_disabled  video_error_or_removed  \
# 0                      0                 0                       0
# 1                      0                 0                       0
# 2                      0                 0                       0
# 3                      0                 0                       0
# 4                      0                 0                       0
# ...                  ...               ...                     ...
# 18799                  0                 0                       0
# 18800                  0                 0                       0
# 18801                  0                 0                       0
# 18802                  0                 0                       0
# 18803                  0                 0                       0
#
#        trending days_difference  category_name  contains_capitalized  \
# 0                             0             10                     1
# 1                             1              1                     0
# 2                             0              3                     0
# 3                             1              3                     1
# 4                             0             12                     1
# ...                         ...            ...                   ...
# 18799                        24              3                     1
# 18800                        25              4                     0
# 18801                        26              3                     1
# 18802                        26             10                     1
# 18803                        26             11                     0
#
#        title_length
# 0                34
# 1                53
# 2                32
# 3                24
# 4                21
# ...             ...
# 18799            19
# 18800            31
# 18801            77
# 18802            52
# 18803            28
#
# [18804 rows x 12 columns]

# %%
x=data.drop("likes",axis=1)
y=data.likes

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print("x_train:",x_train.shape)
print("x_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",x_test.shape)
# Out:
# x_train: (15043, 11)
# x_test: (3761, 11)
# y_train: (15043,)
# y_test: (3761, 11)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ 36130.51472228,  33072.60294286, 135672.17050608, ...,
#         35752.25469313,   7158.71246056,  43151.84908086])

# %%
print("Mean Absolute Error on Training Set:",mean_absolute_error(y_train,model.predict(x_train)))
print("Mean Absolute Error on Testing Set:",mean_absolute_error(y_test,y_pred))
print("R-squared score on Training set:",r2_score(y_train,model.predict(x_train)))
print("R-squared score on Testing set:",r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error on Training Set: 29761.047556079928
# Mean Absolute Error on Testing Set: 31368.171107955506
# R-squared score on Training set: 0.8791650827853803
# R-squared score on Testing set: 0.8911875819347452
